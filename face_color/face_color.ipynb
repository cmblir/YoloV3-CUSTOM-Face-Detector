# %%
import dlib
import face_recognition
image = cv2.imread('/Users/yusin-yeong/python/face_detector/outputs/croped_joli.jpg')
FaceDetector = dlib.get_frontal_face_detector()
faces = FaceDetector(image)
for face in faces:
      x1, y1, x2, y2 = face.left(), face.top(), face.right(), face.bottom()

# %%
image.shape
# Out:
# (268, 267, 3)

# %%
import cv2
import numpy as np
face_img_ycrcb = cv2.cvtColor(image, cv2.COLOR_BGR2YCrCb)

# %%
lower = np.array([0,133,77], dtype = np.uint8)
upper = np.array([255,173,127], dtype = np.uint8)
skin_msk = cv2.inRange(face_img_ycrcb, lower, upper)

# %%
skin = cv2.bitwise_and(image, image, mask = skin_msk)

# %%
import cv2
cv2.imshow('img_color', skin)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.imshow(face_img_ycrcb)
plt.show()

# %%
plt.imshow(skin_msk)
plt.show()
