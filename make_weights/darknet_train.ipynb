# %%
# !nvidia-smi
# Out:
# Sun Mar 20 17:39:33 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P0    29W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
#  4_crop_leaves.ipynb	       'How to get started with Drive.pdf'
#  afce.ipynb		       'My Drive'
#  AI_09_Exam_Sec1.ipynb	        N413.ipynb
#  ai09-sc23x-유신영.ipynb       'Project K-subway users.ipynb'
#  ai-sc13x_reference.ipynb       pytorch_tutorials.ipynb
#  ai-sc41x.ipynb		        train_yolo
#  Codestates		        train_yolov3.ipynb
# 'Colab Notebooks'	        Untitled
#  data			        Untitled0.ipynb
#  datas			        VScode_Colab.ipynb
#  datas.zip		        wider_face_split
#  Doit_Deep_Learning_7_2.ipynb

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# fatal: destination path 'darknet' already exists and is not an empty directory.

# %%
# GPU 사용할 수 있도록 구성하기 (코랩에서는 없어도 됨)
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make
# Out:
# [Errno 20] Not a directory: 'darknet'
# /content/darknet
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %%
# !echo -e '' > data/obj.names
# !echo -e '' > data/obj.data
# !cp /mydrive/train_yolo/data/face.names cfg/face.names
# !cp /mydrive/train_yolo/data/coco.data cfg/coco.data
# !mkdir data/obj
# Out:
# mkdir: cannot create directory ‘data/obj’: File exists

# %%
# Download weights darknet model 53
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2022-03-20 17:41:01--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74.1’
#
# darknet53.conv.74.1 100%[===================>] 154.96M  40.7MB/s    in 4.2s
#
# 2022-03-20 17:41:06 (37.0 MB/s) - ‘darknet53.conv.74.1’ saved [162482580/162482580]

# %%
#!cp cfg/yolov3.cfg cfg/yolov3_training.cfg
# !cp /mydrive/train_yolo/data/yolov3.cfg cfg/yolov3.cfg

# %%
# !unzip /mydrive/train_yolo/images.zip -d data/obj
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: data/obj/images/35_Basketball_playingbasketball_35_353.jpg
#   inflating: data/obj/images/50_Celebration_Or_Party_houseparty_50_84.jpg
#   inflating: data/obj/images/35_Basketball_basketballgame_ball_35_382.jpg
#   inflating: data/obj/images/12_Group_Team_Organized_Group_12_Group_Team_Organized_Group_12_791.jpg
#   inflating: data/obj/images/44_Aerobics_Aerobics_44_251.jpg
#   inflating: data/obj/images/17_Ceremony_Ceremony_17_833.txt
#   inflating: data/obj/images/30_Surgeons_Surgeons_30_289.txt
#   inflating: data/obj/images/36_Football_americanfootball_ball_36_331.jpg
#   inflating: data/obj/images/10_People_Marching_People_Marching_2_476.jpg
#   inflating: data/obj/images/29_Students_Schoolkids_Students_Schoolkids_29_63.txt
#   inflating: data/obj/images/12_Group_Group_12_Group_Group_12_512.jpg
#   inflating: data/obj/images/32_Worker_Laborer_Worker_Laborer_32_771.txt
#   inflating: data/obj/images/41_Swimming_Swimmer_41_214.jpg
# ...

# %%
#import glob
#images_list = glob.glob("data/obj/images/*.jpg")
#images_list = glob.glob("data/obj/*.png")
#print(images_list)

# %%
# 트레이닝 파일 만들기
#file = open("/content/gdrive/MyDrive/train_yolo/data/train.txt", "w") 
#file.write("\n".join(images_list)) 
#file.close()

# %%
# 다크넷에 기존 darknet53.conv.74 모델에 내가 만든 커스텀된 data랑 cfg 학습 시키기
# !./darknet detector train cfg/coco.data cfg/yolov3.cfg darknet53.conv.74 -dont_show
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#  total_bbox = 1929872, rewritten_bbox = 2.605354 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = 0.000294, iou_loss = 0.000000, total_loss = 0.000294
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.821296), count: 4, class_loss = 1.252938, iou_loss = 0.607918, total_loss = 1.860856
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.770828), count: 4, class_loss = 3.162638, iou_loss = 0.666751, total_loss = 3.829389
#  total_bbox = 1929880, rewritten_bbox = 2.605343 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.888727), count: 1, class_loss = 0.009053, iou_loss = 0.064491, total_loss = 0.073544
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000005, iou_loss = 0.000000, total_loss = 0.000005
# ...
